# %%
import sys
import string
import re
import us
import simplejson
from twython import Twython
import matplotlib
import matplotlib.pyplot as plt

from datetime import datetime
from dateutil import parser as dateparser
import time

# # FOR OAUTH AUTHENTICATION -- NEEDED TO ACCESS THE TWITTER API
# twitter = Twython(app_key='lp9Oznlnk6ymCQ6DfpMljZPKW', 
#     app_secret='8lenDoAddurDy3m5Er72C0xfA9LmNf8CJWNCsBBigvyKs',
#     oauth_token='249870075-epMYWAfvhcOyzC9sLvqoySFO248idvDmOoHS2siw',
#     oauth_token_secret='8lenDoAddurDy3m5Er72C0xfA9LmNf8CJWNCsBBigvyKs')

# APP_KEY = 'wGSQamfe1ZCxEvBM9leuT2nmB'
# APP_SECRET = 'rwBQ96pd0JFHkSWh2DTJIz7bSJ6GLayxCmpCRrvHomtPLgLBCb'

# twitter = Twython(APP_KEY, APP_SECRET, oauth_version=2)
# ACCESS_TOKEN = '249870075-epMYWAfvhcOyzC9sLvqoySFO248idvDmOoHS2siw'



APP_KEY = 'wGSQamfe1ZCxEvBM9leuT2nmB'
APP_SECRET = 'rwBQ96pd0JFHkSWh2DTJIz7bSJ6GLayxCmpCRrvHomtPLgLBCb'
twitter = Twython(APP_KEY, APP_SECRET, oauth_version=2)

# store access token permanently in database
ACCESS_TOKEN = twitter.obtain_access_token()

# use the following to make calls for search, etc.
twitter = Twython(APP_KEY, access_token=ACCESS_TOKEN)

# %%
hashtag = 'guncontrol'

# %%
twitter.search(q=hashtag, result_type='recent')
# Out:
# {'search_metadata': {'completed_in': 0.101,
#   'count': 15,
#   'max_id': 970033463943299072,
#   'max_id_str': '970033463943299072',
#   'next_results': '?max_id=970033286075633663&q=guncontrol&include_entities=1&result_type=recent',
#   'query': 'guncontrol',
#   'refresh_url': '?since_id=970033463943299072&q=guncontrol&result_type=recent&include_entities=1',
#   'since_id': 0,
#   'since_id_str': '0'},
#  'statuses': [{'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sat Mar 03 20:29:34 +0000 2018',
#    'entities': {'hashtags': [{'indices': [31, 42], 'text': 'GunControl'}],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/RVAwonk/status…',
#       'expanded_url': 'https://twitter.com/RVAwonk/status/970016224804507648',
#       'indices': [81, 104],
#       'url': 'https://t.co/qIueKG2U6H'}],
#     'user_mentions': []},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 970033463943299072,
#    'id_str': '970033463943299072',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': True,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'quoted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Sat Mar 03 19:21:04 +0000 2018',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#        'expanded_url': 'https://twitter.com/i/web/status/970016224804507648',
#        'indices': [117, 140],
#        'url': 'https://t.co/acYLTbGoUw'}],
#      'user_mentions': []},
#     'favorite_count': 1076,
#     'favorited': False,
#     'geo': None,
#     'id': 970016224804507648,
#     'id_str': '970016224804507648',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 1209,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#     'text': '1:30 PM: The Florida Senate approves a 2-year moratorium on sales of AR-15 assault rifles. \n...\n1:49 PM: The Florid… https://t.co/acYLTbGoUw',
#     'truncated': True,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Wed Jan 29 02:27:58 +0000 2014',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': '#Feminist. Behavioral Scientist.  Freelancer. Writer/Editor @Shareblue Media. Reviving the public scholar & making our information space great again.™',
#      'entities': {'description': {'urls': []}},
#      'favourites_count': 66400,
#      'follow_request_sent': None,
#      'followers_count': 294521,
#      'following': None,
#      'friends_count': 3668,
#      'geo_enabled': False,
#      'has_extended_profile': True,
#      'id': 2316383071,
#      'id_str': '2316383071',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 2949,
#      'location': '',
#      'name': 'Caroline O.',
#      'notifications': None,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2316383071/1465381729',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/754103991966003200/9JwV0DTh_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/754103991966003200/9JwV0DTh_normal.jpg',
#      'profile_link_color': '993377',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'protected': False,
#      'screen_name': 'RVAwonk',
#      'statuses_count': 64996,
#      'time_zone': 'Eastern Time (US & Canada)',
#      'translator_type': 'none',
#      'url': None,
#      'utc_offset': -18000,
#      'verified': False}},
#    'quoted_status_id': 970016224804507648,
#    'quoted_status_id_str': '970016224804507648',
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': "Wow! I didn't realize that the #GunControl problem could be solved THAT quickly. https://t.co/qIueKG2U6H",
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Tue Apr 27 21:01:33 +0000 2010',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'dreamer, shaper, wordsmith,  maker:  working at being me',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 33668,
#     'follow_request_sent': None,
#     'followers_count': 815,
#     'following': None,
#     'friends_count': 1728,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 137812318,
#     'id_str': '137812318',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 10,
#     'location': 'seeking my own place',
#     'name': 'MarieDelaD',
#     'notifications': None,
#     'profile_background_color': '1A1B1F',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/137812318/1518895745',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/744941885458784257/sjRUdYeT_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/744941885458784257/sjRUdYeT_normal.jpg',
#     'profile_link_color': 'E81C4F',
#     'profile_sidebar_border_color': '181A1E',
#     'profile_sidebar_fill_color': '252429',
#     'profile_text_color': '666666',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'MarieDelaD',
#     'statuses_count': 3528,
#     'time_zone': 'Central Time (US & Canada)',
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': -21600,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sat Mar 03 20:29:32 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 878247600096509952,
#       'id_str': '878247600096509952',
#       'indices': [3, 16],
#       'name': 'Candace Owens',
#       'screen_name': 'RealCandaceO'},
#      {'id': 21829541,
#       'id_str': '21829541',
#       'indices': [98, 102],
#       'name': 'NRA',
#       'screen_name': 'NRA'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 970033452761387009,
#    'id_str': '970033452761387009',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 3219,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Sat Mar 03 03:33:32 +0000 2018',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#        'expanded_url': 'https://twitter.com/i/web/status/969777767679188994',
#        'indices': [117, 140],
#        'url': 'https://t.co/76cXf59h81'}],
#      'user_mentions': [{'id': 21829541,
#        'id_str': '21829541',
#        'indices': [80, 84],
#        'name': 'NRA',
#        'screen_name': 'NRA'}]},
#     'favorite_count': 9906,
#     'favorited': False,
#     'geo': None,
#     'id': 969777767679188994,
#     'id_str': '969777767679188994',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 3219,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'text': 'Like so many other American patriots before me, I made the decision to join the @NRA today. I challenge all black A… https://t.co/76cXf59h81',
#     'truncated': True,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Fri Jun 23 13:45:19 +0000 2017',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': '"I never imagined it. I just kept going." Vlogger. Director of Urban Engagement for @TPUSA https://t.co/N9uZpw46QI',
#      'entities': {'description': {'urls': [{'display_url': 'TPUSA.COM/JOIN',
#          'expanded_url': 'http://WWW.TPUSA.COM/JOIN',
#          'indices': [91, 114],
#          'url': 'https://t.co/N9uZpw46QI'}]},
#       'url': {'urls': [{'display_url': 'm.youtube.com/channel/UCL0u5…',
#          'expanded_url': 'https://m.youtube.com/channel/UCL0u5uz7KZ9q-pe-VC8TY-w',
#          'indices': [0, 23],
#          'url': 'https://t.co/JJmEKPWR0B'}]}},
#      'favourites_count': 10985,
#      'follow_request_sent': None,
#      'followers_count': 145984,
#      'following': None,
#      'friends_count': 292,
#      'geo_enabled': False,
#      'has_extended_profile': True,
#      'id': 878247600096509952,
#      'id_str': '878247600096509952',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 652,
#      'location': 'New York, USA',
#      'name': 'Candace Owens',
#      'notifications': None,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/878247600096509952/1511373859',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/933382279279366147/VeRe5bs1_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/933382279279366147/VeRe5bs1_normal.jpg',
#      'profile_link_color': 'ABB8C2',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'protected': False,
#      'screen_name': 'RealCandaceO',
#      'statuses_count': 873,
#      'time_zone': 'Eastern Time (US & Canada)',
#      'translator_type': 'none',
#      'url': 'https://t.co/JJmEKPWR0B',
#      'utc_offset': -18000,
#      'verified': False}},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'text': 'RT @RealCandaceO: Like so many other American patriots before me, I made the decision to join the @NRA today. I challenge all black America…',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Thu May 25 01:21:15 +0000 2017',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'I am a working class country lady who has Conservative values. I love the outdoors. I am a Christian. Married to a retired US Marine. I follow back. #MAGA',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 3523,
#     'follow_request_sent': None,
#     'followers_count': 293,
#     'following': None,
#     'friends_count': 194,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 867551100076994560,
#     'id_str': '867551100076994560',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 1,
#     'location': '',
#     'name': 'Carolyn Holland',
#     'notifications': None,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/867551100076994560/1495929798',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/868618651276128257/v-r3lsfV_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/868618651276128257/v-r3lsfV_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'Cholland2000',
#     'statuses_count': 7419,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sat Mar 03 20:29:30 +0000 2018',
#    'entities': {'hashtags': [{'indices': [77, 96],
#       'text': 'ThoughtsAndPrayers'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 1046114347,
#       'id_str': '1046114347',
#       'indices': [3, 19],
#       'name': '(((B. Paul Stuart)))',
#       'screen_name': 'BrianPaulStuart'},
#      {'id': 15207668,
#       'id_str': '15207668',
#       'indices': [22, 31],
#       'name': 'House Republicans',
#       'screen_name': 'HouseGOP'},
#      {'id': 14344823,
#       'id_str': '14344823',
#       'indices': [33, 43],
#       'name': 'Senate Republicans',
#       'screen_name': 'SenateGOP'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 970033444372676608,
#    'id_str': '970033444372676608',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 26,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Sat Mar 03 15:53:39 +0000 2018',
#     'entities': {'hashtags': [{'indices': [56, 75],
#        'text': 'ThoughtsAndPrayers'}],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#        'expanded_url': 'https://twitter.com/i/web/status/969964025424629760',
#        'indices': [117, 140],
#        'url': 'https://t.co/N2PU4tU3WV'}],
#      'user_mentions': [{'id': 15207668,
#        'id_str': '15207668',
#        'indices': [1, 10],
#        'name': 'House Republicans',
#        'screen_name': 'HouseGOP'},
#       {'id': 14344823,
#        'id_str': '14344823',
#        'indices': [12, 22],
#        'name': 'Senate Republicans',
#        'screen_name': 'SenateGOP'}]},
#     'favorite_count': 30,
#     'favorited': False,
#     'geo': None,
#     'id': 969964025424629760,
#     'id_str': '969964025424629760',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 26,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'text': '.@HouseGOP, @SenateGOP:\nFor every disingenuous dose of “#ThoughtsAndPrayers” you craven NRA whores serve families o… https://t.co/N2PU4tU3WV',
#     'truncated': True,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Sat Dec 29 22:03:09 +0000 2012',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': "Cynic's idealist. Idealist's cynic. Atheist, humanist, and feminist. Liberal, Democrat. Equality. Unite Blue. RESIST.",
#      'entities': {'description': {'urls': []}},
#      'favourites_count': 80126,
#      'follow_request_sent': None,
#      'followers_count': 19217,
#      'following': None,
#      'friends_count': 19283,
#      'geo_enabled': True,
#      'has_extended_profile': False,
#      'id': 1046114347,
#      'id_str': '1046114347',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 273,
#      'location': '',
#      'name': '(((B. Paul Stuart)))',
#      'notifications': None,
#      'profile_background_color': '131516',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#      'profile_background_tile': True,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1046114347/1401944456',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/473653086729166850/0FJRCBy-_normal.png',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/473653086729166850/0FJRCBy-_normal.png',
#      'profile_link_color': '009999',
#      'profile_sidebar_border_color': 'EEEEEE',
#      'profile_sidebar_fill_color': 'EFEFEF',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'BrianPaulStuart',
#      'statuses_count': 97920,
#      'time_zone': 'Eastern Time (US & Canada)',
#      'translator_type': 'none',
#      'url': None,
#      'utc_offset': -18000,
#      'verified': False}},
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': 'RT @BrianPaulStuart: .@HouseGOP, @SenateGOP:\nFor every disingenuous dose of “#ThoughtsAndPrayers” you craven NRA whores serve families of #…',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sun Apr 16 20:00:25 +0000 2017',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Recently escaped from redneckville. Live to ride horses in the sunshine and defend our democracy from those who wish 2 destroy it. #indivisible #resist',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 9893,
#     'follow_request_sent': None,
#     'followers_count': 2961,
#     'following': None,
#     'friends_count': 4995,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 853699622795067392,
#     'id_str': '853699622795067392',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 5,
#     'location': 'LeftCoast',
#     'name': 'CaliforniaThunderSno',
#     'notifications': None,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/853699622795067392/1492373442',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/853702873758089216/PQxk89yJ_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/853702873758089216/PQxk89yJ_normal.jpg',
#     'profile_link_color': '7FDBB6',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'CalThunderSnow',
#     'statuses_count': 15201,
#     'time_zone': 'Pacific Time (US & Canada)',
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': -28800,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sat Mar 03 20:29:28 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 1561077758,
#       'id_str': '1561077758',
#       'indices': [3, 16],
#       'name': 'Elder Lansing',
#       'screen_name': 'ElderLansing'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 970033438379134976,
#    'id_str': '970033438379134976',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 442,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Sat Mar 03 18:33:03 +0000 2018',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#        'expanded_url': 'https://twitter.com/i/web/status/970004139433439234',
#        'indices': [117, 140],
#        'url': 'https://t.co/fbQxHRPHeM'}],
#      'user_mentions': []},
#     'favorite_count': 948,
#     'favorited': False,
#     'geo': None,
#     'id': 970004139433439234,
#     'id_str': '970004139433439234',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'retweet_count': 442,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'text': "If you want your home and car gun free that's on you. If you want law abiding U.S. citizens to turn in their guns a… https://t.co/fbQxHRPHeM",
#     'truncated': True,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Mon Jul 01 17:38:48 +0000 2013',
#      'default_profile': True,
#      'default_profile_image': False,
#      'description': 'Elder, True Light Pentecost Church Spartanburg, SC under the guidance of Prophet Bishop H. Walker, Pro Trump! Blocked by Shaun King, Tariq Nasheed, April Ryan',
#      'entities': {'description': {'urls': []}},
#      'favourites_count': 49884,
#      'follow_request_sent': None,
#      'followers_count': 75055,
#      'following': None,
#      'friends_count': 38262,
#      'geo_enabled': True,
#      'has_extended_profile': False,
#      'id': 1561077758,
#      'id_str': '1561077758',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 318,
#      'location': '',
#      'name': 'Elder Lansing',
#      'notifications': None,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/935931103952756738/MArVstmY_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/935931103952756738/MArVstmY_normal.jpg',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'ElderLansing',
#      'statuses_count': 11023,
#      'time_zone': 'Atlantic Time (Canada)',
#      'translator_type': 'none',
#      'url': None,
#      'utc_offset': -14400,
#      'verified': False}},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'text': "RT @ElderLansing: If you want your home and car gun free that's on you. If you want law abiding U.S. citizens to turn in their guns and con…",
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Thu Jan 24 05:46:44 +0000 2013',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': '1970 #Buick #GSX #Matilda. @CoolRidesOnline Champion DavidC77 @GoldEagleCo & @303Products / #Akita #Dogs / #2A, @NRA Life, @GOALupdate Life. / @NASCAR / 😎',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 62551,
#     'follow_request_sent': None,
#     'followers_count': 2840,
#     'following': None,
#     'friends_count': 2510,
#     'geo_enabled': True,
#     'has_extended_profile': True,
#     'id': 1116070057,
#     'id_str': '1116070057',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 147,
#     'location': 'Westhampton, MA, USA',
#     'name': 'David M. Cleveland',
#     'notifications': None,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1116070057/1453660922',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/3155713286/a076ad6c788c9c589ca3a5354bc419e4_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/3155713286/a076ad6c788c9c589ca3a5354bc419e4_normal.jpeg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'David70BuickGSX',
#     'statuses_count': 64441,
#     'time_zone': 'Eastern Time (US & Canada)',
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': -18000,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sat Mar 03 20:29:25 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 43945628,
#       'id_str': '43945628',
#       'indices': [3, 14],
#       'name': 'Troy Kinsey',
#       'screen_name': 'TroyKinsey'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 970033424747687937,
#    'id_str': '970033424747687937',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 20,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Sat Mar 03 19:09:56 +0000 2018',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#        'expanded_url': 'https://twitter.com/i/web/status/970013424104230912',
#        'indices': [117, 140],
#        'url': 'https://t.co/Hz2og5u9TT'}],
#      'user_mentions': []},
#     'favorite_count': 21,
#     'favorited': False,
#     'geo': None,
#     'id': 970013424104230912,
#     'id_str': '970013424104230912',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'retweet_count': 20,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'text': "About that assault-style weapon moratorium the FL Senate briefly approved: after the chamber's reversal on reconsid… https://t.co/Hz2og5u9TT",
#     'truncated': True,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Mon Jun 01 19:00:04 +0000 2009',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': '#Florida Capitol reporter for Bay News 9 (Tampa/St. Pete) & News 13 (Orlando). @USC & @FloridaState alum. Commercial pilot. Current @FLPressCorps president.',
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'baynews9.com/about/reporter…',
#          'expanded_url': 'http://www.baynews9.com/about/reporters-troy-kinsey',
#          'indices': [0, 23],
#          'url': 'https://t.co/aNt58gwxpZ'}]}},
#      'favourites_count': 1029,
#      'follow_request_sent': None,
#      'followers_count': 7047,
#      'following': None,
#      'friends_count': 3796,
#      'geo_enabled': True,
#      'has_extended_profile': True,
#      'id': 43945628,
#      'id_str': '43945628',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 316,
#      'location': 'Tallahassee, FL',
#      'name': 'Troy Kinsey',
#      'notifications': None,
#      'profile_background_color': '022330',
#      'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/105213272/Capital.jpg',
#      'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/105213272/Capital.jpg',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/43945628/1411066960',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/533437087/Troy_Kinsey2_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/533437087/Troy_Kinsey2_normal.jpg',
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': 'A8C7F7',
#      'profile_sidebar_fill_color': 'C0DFEC',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'TroyKinsey',
#      'statuses_count': 13709,
#      'time_zone': 'Quito',
#      'translator_type': 'none',
#      'url': 'https://t.co/aNt58gwxpZ',
#      'utc_offset': -18000,
#      'verified': True}},
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': "RT @TroyKinsey: About that assault-style weapon moratorium the FL Senate briefly approved: after the chamber's reversal on reconsideration,…",
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sat Apr 14 20:55:35 +0000 2012',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Love music, movies, books, tv-shows. Politics, Laughter. Kindness is everything. Although with Trumpsters...it is so hard!',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 59226,
#     'follow_request_sent': None,
#     'followers_count': 633,
#     'following': None,
#     'friends_count': 249,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 553828418,
#     'id_str': '553828418',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 3,
#     'location': 'Sunshine State. ',
#     'name': 'irina fowzry',
#     'notifications': None,
#     'profile_background_color': '642D8B',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/576228760/rzvw6fhqmuu94n75ahyu.jpeg',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/576228760/rzvw6fhqmuu94n75ahyu.jpeg',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/2171525301/2457472640060501294S425x425Q85_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/2171525301/2457472640060501294S425x425Q85_normal.jpg',
#     'profile_link_color': 'FF0000',
#     'profile_sidebar_border_color': '65B0DA',
#     'profile_sidebar_fill_color': '7AC3EE',
#     'profile_text_color': '3D1957',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'irinafowzry',
#     'statuses_count': 20029,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sat Mar 03 20:29:25 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#       'expanded_url': 'https://twitter.com/i/web/status/970033422893768705',
#       'indices': [117, 140],
#       'url': 'https://t.co/BN9RZXLvwZ'}],
#     'user_mentions': [{'id': 964032914626359296,
#       'id_str': '964032914626359296',
#       'indices': [0, 14],
#       'name': 'Cameron Kasky',
#       'screen_name': 'cameron_kasky'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 970033422893768705,
#    'id_str': '970033422893768705',
#    'in_reply_to_screen_name': 'cameron_kasky',
#    'in_reply_to_status_id': 969427617941254144,
#    'in_reply_to_status_id_str': '969427617941254144',
#    'in_reply_to_user_id': 964032914626359296,
#    'in_reply_to_user_id_str': '964032914626359296',
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': "@cameron_kasky Go get'em.  Good job last night. You two are right: Civics lessons should start before senior yr. Pe… https://t.co/BN9RZXLvwZ",
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Wed Jun 22 22:03:27 +0000 2016',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'STILL Fired Up! Scribbler. Campaign staffer back in the day #Elections2018 #FBR #StrongerTogether Natural #Resistance to Bullsh*t',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 38596,
#     'follow_request_sent': None,
#     'followers_count': 894,
#     'following': None,
#     'friends_count': 1467,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 745738999826886658,
#     'id_str': '745738999826886658',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 13,
#     'location': 'Sanctuary City, Philly',
#     'name': 'Jane Dupree',
#     'notifications': None,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/745738999826886658/1518969765',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/967147499143053312/W1lLV9sF_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/967147499143053312/W1lLV9sF_normal.png',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'JaneDupree1',
#     'statuses_count': 7226,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sat Mar 03 20:29:22 +0000 2018',
#    'entities': {'hashtags': [{'indices': [28, 39], 'text': 'guncontrol'},
#      {'indices': [42, 46], 'text': 'Gun'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 3405962098,
#       'id_str': '3405962098',
#       'indices': [3, 12],
#       'name': 'MAGA MEL 🇺🇸',
#       'screen_name': 'MEL2AUSA'},
#      {'id': 232901331,
#       'id_str': '232901331',
#       'indices': [15, 24],
#       'name': 'Dan Bongino',
#       'screen_name': 'dbongino'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 970033413787828229,
#    'id_str': '970033413787828229',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 625,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Sat Mar 03 02:04:58 +0000 2018',
#     'entities': {'hashtags': [{'indices': [14, 25], 'text': 'guncontrol'},
#       {'indices': [28, 32], 'text': 'Gun'}],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#        'expanded_url': 'https://twitter.com/i/web/status/969755481316130816',
#        'indices': [116, 139],
#        'url': 'https://t.co/omHX0hu4ED'}],
#      'user_mentions': [{'id': 232901331,
#        'id_str': '232901331',
#        'indices': [1, 10],
#        'name': 'Dan Bongino',
#        'screen_name': 'dbongino'}]},
#     'favorite_count': 829,
#     'favorited': False,
#     'geo': None,
#     'id': 969755481316130816,
#     'id_str': '969755481316130816',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 625,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#     'text': '.@dbongino on #guncontrol: "#Gun laws are the only laws that affect the law abiding and don\'t affect criminals one… https://t.co/omHX0hu4ED',
#     'truncated': True,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Thu Aug 06 17:19:53 +0000 2015',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': '"There is nothing in the world so irresistibly contagious as laughter & good humor." Charles Dickens 🇺🇸 #Patriot #2A🔫#TRUMP #MAGA #BuildTheWall 👉🏼 NO LISTS',
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'gab.ai/MAGA9MM',
#          'expanded_url': 'http://gab.ai/MAGA9MM',
#          'indices': [0, 23],
#          'url': 'https://t.co/bUXZzf0ILn'}]}},
#      'favourites_count': 69516,
#      'follow_request_sent': None,
#      'followers_count': 38459,
#      'following': None,
#      'friends_count': 23005,
#      'geo_enabled': False,
#      'has_extended_profile': False,
#      'id': 3405962098,
#      'id_str': '3405962098',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 19,
#      'location': 'USA',
#      'name': 'MAGA MEL 🇺🇸',
#      'notifications': None,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3405962098/1508796331',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/956447098332905472/y0BIeoGJ_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/956447098332905472/y0BIeoGJ_normal.jpg',
#      'profile_link_color': '3B94D9',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'protected': False,
#      'screen_name': 'MEL2AUSA',
#      'statuses_count': 60889,
#      'time_zone': 'Pacific Time (US & Canada)',
#      'translator_type': 'none',
#      'url': 'https://t.co/bUXZzf0ILn',
#      'utc_offset': -28800,
#      'verified': False}},
#    'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#    'text': 'RT @MEL2AUSA: .@dbongino on #guncontrol: "#Gun laws are the only laws that affect the law abiding and don\'t affect criminals one bit." #Def…',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Mon Mar 26 22:09:25 +0000 2012',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': "God's Grace~RN~DAR~Animal Welfare~Freelance Writer~ #Police #Military #Inspiration~OD’d on Politics. I treasure my friends. #MAGA",
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 40560,
#     'follow_request_sent': None,
#     'followers_count': 10659,
#     'following': None,
#     'friends_count': 5744,
#     'geo_enabled': True,
#     'has_extended_profile': True,
#     'id': 537602851,
#     'id_str': '537602851',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 396,
#     'location': 'Right Here',
#     'name': '🙏🏼 ❤️Gr8fulNurse 🇺🇸🇮🇱',
#     'notifications': None,
#     'profile_background_color': '642D8B',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/634912270951165952/mLjT4zx1.jpg',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/634912270951165952/mLjT4zx1.jpg',
#     'profile_background_tile': True,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/537602851/1519926195',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/967668501061156864/0eglw586_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/967668501061156864/0eglw586_normal.jpg',
#     'profile_link_color': '3B94D9',
#     'profile_sidebar_border_color': '65B0DA',
#     'profile_sidebar_fill_color': '7AC3EE',
#     'profile_text_color': '3D1957',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'WA_SusanD',
#     'statuses_count': 204273,
#     'time_zone': 'America/Denver',
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': -25200,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sat Mar 03 20:29:22 +0000 2018',
#    'entities': {'hashtags': [{'indices': [66, 77], 'text': 'GunControl'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': []},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 970033412793872387,
#    'id_str': '970033412793872387',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': "When my gun jams I look down the business end to see what's wrong #GunControl",
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Thu Apr 09 11:55:30 +0000 2015',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'Im Alec Window fishing is the only thing i live for and if you dont yee yee like me then youll get an elbow to the throat..kill deer (not actually Alec)',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'fish.com',
#         'expanded_url': 'http://fish.com',
#         'indices': [0, 23],
#         'url': 'https://t.co/CcJ0kkyUZR'}]}},
#     'favourites_count': 208,
#     'follow_request_sent': None,
#     'followers_count': 97,
#     'following': None,
#     'friends_count': 514,
#     'geo_enabled': False,
#     'has_extended_profile': True,
#     'id': 3146001606,
#     'id_str': '3146001606',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 0,
#     'location': 'Morgantown, WV',
#     'name': 'Aleik winetho',
#     'notifications': None,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3146001606/1490571108',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/907789184164823040/FiLehG4Y_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/907789184164823040/FiLehG4Y_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'FishBoyAlec',
#     'statuses_count': 460,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': 'https://t.co/CcJ0kkyUZR',
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sat Mar 03 20:29:13 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 195271137,
#       'id_str': '195271137',
#       'indices': [3, 14],
#       'name': 'Larry Elder',
#       'screen_name': 'larryelder'},
#      {'id': 25073877,
#       'id_str': '25073877',
#       'indices': [36, 52],
#       'name': 'Donald J. Trump',
#       'screen_name': 'realDonaldTrump'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 970033375711932416,
#    'id_str': '970033375711932416',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 523,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Sat Mar 03 16:58:26 +0000 2018',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#        'expanded_url': 'https://twitter.com/i/web/status/969980328721899520',
#        'indices': [117, 140],
#        'url': 'https://t.co/GR0DWp0Ixl'}],
#      'user_mentions': [{'id': 25073877,
#        'id_str': '25073877',
#        'indices': [20, 36],
#        'name': 'Donald J. Trump',
#        'screen_name': 'realDonaldTrump'}]},
#     'favorite_count': 1332,
#     'favorited': False,
#     'geo': None,
#     'id': 969980328721899520,
#     'id_str': '969980328721899520',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'retweet_count': 523,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#     'text': 'Many liberals call  @realDonaldTrump a "dictator." Many conservatives believe the FBI and the "deep state" are tryi… https://t.co/GR0DWp0Ixl',
#     'truncated': True,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Sun Sep 26 07:34:31 +0000 2010',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': 'Sage from South Central; Larry Elder Show; Salem/CRN; (KRLA L.A. 6-9p PT); 6-9p ET; (888) 971-SAGE; https://t.co/sXv5JWRKRA',
#      'entities': {'description': {'urls': [{'display_url': 'elderstatement.com',
#          'expanded_url': 'http://www.elderstatement.com',
#          'indices': [100, 123],
#          'url': 'https://t.co/sXv5JWRKRA'}]},
#       'url': {'urls': [{'display_url': 'larryelder.com/membership',
#          'expanded_url': 'http://www.larryelder.com/membership',
#          'indices': [0, 23],
#          'url': 'https://t.co/htHywSGbPA'}]}},
#      'favourites_count': 1930,
#      'follow_request_sent': None,
#      'followers_count': 333693,
#      'following': None,
#      'friends_count': 99,
#      'geo_enabled': True,
#      'has_extended_profile': False,
#      'id': 195271137,
#      'id_str': '195271137',
#      'is_translation_enabled': False,
# ...
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3064002562/1424967913',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/570980091971121152/Xqc3HCI6_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/570980091971121152/Xqc3HCI6_normal.jpeg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'BBalings',
#     'statuses_count': 141654,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': 'https://t.co/5isxplsfYd',
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sat Mar 03 20:28:55 +0000 2018',
#    'entities': {'hashtags': [{'indices': [0, 10], 'text': 'MSDStrong'},
#      {'indices': [11, 22], 'text': 'GunControl'},
#      {'indices': [23, 34], 'text': 'NeverAgain'},
#      {'indices': [35, 53], 'text': 'douglashighschool'},
#      {'indices': [54, 68], 'text': 'JoaquinOliver'},
#      {'indices': [69, 85], 'text': '17innocentlives'}],
#     'media': [{'display_url': 'pic.twitter.com/PnwDFlrtTG',
#       'expanded_url': 'https://twitter.com/RLaryss/status/970033298356436992/photo/1',
#       'id': 970033284347346944,
#       'id_str': '970033284347346944',
#       'indices': [86, 109],
#       'media_url': 'http://pbs.twimg.com/media/DXZAIfXUQAAjVV4.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/DXZAIfXUQAAjVV4.jpg',
#       'sizes': {'large': {'h': 1334, 'resize': 'fit', 'w': 750},
#        'medium': {'h': 1200, 'resize': 'fit', 'w': 675},
#        'small': {'h': 680, 'resize': 'fit', 'w': 382},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/PnwDFlrtTG'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': []},
#    'extended_entities': {'media': [{'display_url': 'pic.twitter.com/PnwDFlrtTG',
#       'expanded_url': 'https://twitter.com/RLaryss/status/970033298356436992/photo/1',
#       'id': 970033284347346944,
#       'id_str': '970033284347346944',
#       'indices': [86, 109],
#       'media_url': 'http://pbs.twimg.com/media/DXZAIfXUQAAjVV4.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/DXZAIfXUQAAjVV4.jpg',
#       'sizes': {'large': {'h': 1334, 'resize': 'fit', 'w': 750},
#        'medium': {'h': 1200, 'resize': 'fit', 'w': 675},
#        'small': {'h': 680, 'resize': 'fit', 'w': 382},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/PnwDFlrtTG'},
#      {'display_url': 'pic.twitter.com/PnwDFlrtTG',
#       'expanded_url': 'https://twitter.com/RLaryss/status/970033298356436992/photo/1',
#       'id': 970033284364161024,
#       'id_str': '970033284364161024',
#       'indices': [86, 109],
#       'media_url': 'http://pbs.twimg.com/media/DXZAIfbU0AAPCQk.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/DXZAIfbU0AAPCQk.jpg',
#       'sizes': {'large': {'h': 750, 'resize': 'fit', 'w': 1334},
#        'medium': {'h': 675, 'resize': 'fit', 'w': 1200},
#        'small': {'h': 382, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/PnwDFlrtTG'},
#      {'display_url': 'pic.twitter.com/PnwDFlrtTG',
#       'expanded_url': 'https://twitter.com/RLaryss/status/970033298356436992/photo/1',
#       'id': 970033284313841664,
#       'id_str': '970033284313841664',
#       'indices': [86, 109],
#       'media_url': 'http://pbs.twimg.com/media/DXZAIfPVAAAg28X.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/DXZAIfPVAAAg28X.jpg',
#       'sizes': {'large': {'h': 1334, 'resize': 'fit', 'w': 750},
#        'medium': {'h': 1200, 'resize': 'fit', 'w': 675},
#        'small': {'h': 680, 'resize': 'fit', 'w': 382},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/PnwDFlrtTG'},
#      {'display_url': 'pic.twitter.com/PnwDFlrtTG',
#       'expanded_url': 'https://twitter.com/RLaryss/status/970033298356436992/photo/1',
#       'id': 970033284401922048,
#       'id_str': '970033284401922048',
#       'indices': [86, 109],
#       'media_url': 'http://pbs.twimg.com/media/DXZAIfkVAAAuPi0.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/DXZAIfkVAAAuPi0.jpg',
#       'sizes': {'large': {'h': 1334, 'resize': 'fit', 'w': 750},
#        'medium': {'h': 1200, 'resize': 'fit', 'w': 675},
#        'small': {'h': 680, 'resize': 'fit', 'w': 382},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/PnwDFlrtTG'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 970033298356436992,
#    'id_str': '970033298356436992',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'und',
#    'metadata': {'iso_language_code': 'und', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': '#MSDStrong #GunControl #NeverAgain #douglashighschool #JoaquinOliver #17innocentlives https://t.co/PnwDFlrtTG',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Tue Nov 26 18:14:41 +0000 2013',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'Sc x Laryssrodriguez ☃️',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 591,
#     'follow_request_sent': None,
#     'followers_count': 113,
#     'following': None,
#     'friends_count': 235,
#     'geo_enabled': False,
#     'has_extended_profile': True,
#     'id': 2216151259,
#     'id_str': '2216151259',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 1,
#     'location': '',
#     'name': 'Laryss Rheannon R. 🌙',
#     'notifications': None,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2216151259/1515095186',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/969707414856577025/IlHNhmxj_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/969707414856577025/IlHNhmxj_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'RLaryss',
#     'statuses_count': 227,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sat Mar 03 20:28:53 +0000 2018',
#    'entities': {'hashtags': [{'indices': [50, 66], 'text': 'dishonestdonald'},
#      {'indices': [118, 129], 'text': 'GunControl'},
#      {'indices': [130, 139], 'text': 'DReamers'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 825414170535399425,
#       'id_str': '825414170535399425',
#       'indices': [3, 17],
#       'name': 'Sarah Jane 🇺🇸',
#       'screen_name': 'wordsmatter01'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 970033288629940224,
#    'id_str': '970033288629940224',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 6,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Sat Mar 03 17:54:59 +0000 2018',
#     'entities': {'hashtags': [{'indices': [31, 47], 'text': 'dishonestdonald'},
#       {'indices': [99, 110], 'text': 'GunControl'}],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#        'expanded_url': 'https://twitter.com/i/web/status/969994558498115589',
#        'indices': [112, 135],
#        'url': 'https://t.co/LPMGlPB6IS'}],
#      'user_mentions': []},
#     'favorite_count': 9,
#     'favorited': False,
#     'geo': None,
#     'id': 969994558498115589,
#     'id_str': '969994558498115589',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'retweet_count': 6,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'text': 'This great nation will survive #dishonestdonald but only if people stand up and not remain silent.\n#GunControl… https://t.co/LPMGlPB6IS',
#     'truncated': True,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Sat Jan 28 18:44:08 +0000 2017',
#      'default_profile': True,
#      'default_profile_image': False,
#      'description': 'I will always say NO to Trump - my opinions are my own. I love my country-work in U.K. 🇺🇸 #TheResistance',
#      'entities': {'description': {'urls': []}},
#      'favourites_count': 9146,
#      'follow_request_sent': None,
#      'followers_count': 175,
#      'following': None,
#      'friends_count': 890,
#      'geo_enabled': True,
#      'has_extended_profile': False,
#      'id': 825414170535399425,
#      'id_str': '825414170535399425',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en-gb',
#      'listed_count': 4,
#      'location': '',
#      'name': 'Sarah Jane 🇺🇸',
#      'notifications': None,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/825414170535399425/1514814244',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/947827530710634497/yEvsG0AR_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/947827530710634497/yEvsG0AR_normal.jpg',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'wordsmatter01',
#      'statuses_count': 6268,
#      'time_zone': 'Pacific Time (US & Canada)',
#      'translator_type': 'none',
#      'url': None,
#      'utc_offset': -28800,
#      'verified': False}},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'text': 'RT @wordsmatter01: This great nation will survive #dishonestdonald but only if people stand up and not remain silent.\n#GunControl #DReamers…',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Wed Dec 12 04:53:37 +0000 2007',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Dedicated to being curious because I am and always have been. Also an indiscriminate follower of fellow Twitterers just because I can.',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 4470,
#     'follow_request_sent': None,
#     'followers_count': 304,
#     'following': None,
#     'friends_count': 1037,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 11076222,
#     'id_str': '11076222',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 6,
#     'location': 'Kansas',
#     'name': 'Sandra Linville',
#     'notifications': None,
#     'profile_background_color': '352726',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme5/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme5/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1149227994/SLT_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1149227994/SLT_normal.jpg',
#     'profile_link_color': 'D02B55',
#     'profile_sidebar_border_color': '829D5E',
#     'profile_sidebar_fill_color': '99CC33',
#     'profile_text_color': '3E4415',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'linville',
#     'statuses_count': 5172,
#     'time_zone': 'Central Time (US & Canada)',
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': -21600,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sat Mar 03 20:28:52 +0000 2018',
#    'entities': {'hashtags': [{'indices': [67, 78], 'text': 'GunControl'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': []},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 970033286075633664,
#    'id_str': '970033286075633664',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': 'I blew this squirrels head clean off his shoulders with a 12 gauge #GunControl',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Thu Apr 09 11:55:30 +0000 2015',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'Im Alec Window fishing is the only thing i live for and if you dont yee yee like me then youll get an elbow to the throat..kill deer (not actually Alec)',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'fish.com',
#         'expanded_url': 'http://fish.com',
#         'indices': [0, 23],
#         'url': 'https://t.co/CcJ0kkyUZR'}]}},
#     'favourites_count': 208,
#     'follow_request_sent': None,
#     'followers_count': 97,
#     'following': None,
#     'friends_count': 514,
#     'geo_enabled': False,
#     'has_extended_profile': True,
#     'id': 3146001606,
#     'id_str': '3146001606',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 0,
#     'location': 'Morgantown, WV',
#     'name': 'Aleik winetho',
#     'notifications': None,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3146001606/1490571108',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/907789184164823040/FiLehG4Y_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/907789184164823040/FiLehG4Y_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'FishBoyAlec',
#     'statuses_count': 460,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': 'https://t.co/CcJ0kkyUZR',
#     'utc_offset': None,
#     'verified': False}}]}

# %%
hashtag_search = twitter.search(q=hashtag, result_type='recent')

# %%
hashtag_search['statuses'][0]['user']['location']
# Out:
# 'Netherlands'

# %%
location = hashtag_search['statuses'][0]['user']['location'].split('.')
location = ''.join(location)

location = location.split(',')
location = ''.join(location)
location = location.strip()
location
# ''.join(location)
# Out:
# 'Netherlands'

# %%
for n in range(0,len(location)) :
    name=n
name
# Out:
# 10

# %%
states = ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DC", "DE", "Fl", "GA", 
          "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", 
          "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", 
          "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", 
          "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"]

print(location)

for n in range(0,len(states)) :
        if states[n] in location:
            location = states[n]
            print('location: ' + location)
        else:
            location = "not a state"
# Out:
# Netherlands

# %%
location
# Out:
# 'not a state'
